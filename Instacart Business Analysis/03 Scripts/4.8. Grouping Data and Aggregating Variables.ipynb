# %% [markdown]
# ## Importing libraries

# %%
# Importing Libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## Importing Dataframes

# %%
# Define path
path = r'/Users/isaacotubanjo/Documents/08:08:2023 Instacart Business Analysis'

# %%
# Import orders_products_with_new_variables.pkl as df_ords_prods_merge
df_ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_with_new_variables.pkl'))

# %% [markdown]
# ## Using the GroupBy Function

# %%
# Using groupby function and aggregating the mean 
df_ords_prods_merge.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# The mean here varies less than the mean in the subset (difference between the highest and lowest means in the subset is 8.17 while the difference in the entire dataframe is 7.69. This is even reduced further when you take out the department id 21 which represents the missing category and has the highest mean). The values are also slightly reduced (for example: department id 4 with 17.81 in the full dataframe and 18.82 in the subset).

# %% [markdown]
# ## Aggregating Data with Transform

# %%
# Splitting into groups and generating a new column 
df_ords_prods_merge['max_order'] = df_ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
# To confirm this was executed successfully, we can view the first 50 rows of the dataframe
pd.options.display.max_rows = None
# This will remove the view restriction on Python

# %%
df_ords_prods_merge.head(50)
# Out:
#     order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                  2                  8
# 1    2398795        1             2                  3                  7
# 2     473747        1             3                  3                 12
# 3    2254736        1             4                  4                  7
# 4     431534        1             5                  4                 15
# 5    3367565        1             6                  2                  7
# 6     550135        1             7                  1                  9
# 7    3108588        1             8                  1                 14
# 8    2295261        1             9                  1                 16
# 9    2550362        1            10                  4                  8
# 10   2968173       15            15                  1                  9
# 11   1870022       15            17                  2                 16
# 12   1911383       15            18                  2                 11
# 13   2715276       15            21                  1                  9
# 14    487368       15            22                  1                 10
# 15   2293453       19             2                  5                 14
# 16   1973799       19             5                  6                 12
# 17    532817       19             7                  4                 17
# 18   1573906       21            10                  3                 10
# 19   1593000       31            10                  3                  8
# 20   2231262       31            17                  3                 11
# 21   2580647       43             6                  4                 16
# 22   2187180       43             9                  4                 12
# 23   2497897       52             1                  1                  9
# 24   1318871       52             2                  1                 10
# 25   1261384       52             3                  1                 10
# 26    580568       52             5                  2                 10
# 27   2428073       52             7                  2                  7
# 28    342306       52             9                  1                 11
# 29   1520353       52            10                  2                 10
# 30   2542086       52            11                  2                  9
# 31    944694       52            12                  1                 16
# 32   1268191       52            15                  2                 11
# 33   1122089       52            17                  2                 10
# 34   1498922       52            18                  2                 10
# 35    180919       52            19                  3                  8
# 36   2695875       52            21                  5                 10
# 37   3205960       67             1                  3                 11
# 38    970922       67             2                  1                 15
# 39    596585       67             3                  1                 13
# 40   2037087       67             4                  2                  9
# 41   2474111       67             5                  3                 14
# 42   1568481       67             6                  3                 12
# 43   2048527       67             8                  2                 11
# 44   2389031       67             9                  2                 14
# 45   2378562       67            10                  1                 10
# 46   1515698       67            11                  1                 11
# 47   1928050       67            12                  2                 12
# 48   1949274       67            13                  1                 10
# 49    551869       67            14                  1                  9
#
#     days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
# 5                    19.0         196                  1          1
# 6                    20.0         196                  1          1
# 7                    14.0         196                  2          1
# 8                     0.0         196                  4          1
# 9                    30.0         196                  1          1
# 10                    7.0         196                  2          0
# 11                    8.0         196                  6          1
# 12                    7.0         196                  1          1
# 13                    7.0         196                  1          1
# 14                   14.0         196                  1          1
# 15                    6.0         196                  3          0
# 16                    8.0         196                 15          1
# 17                    6.0         196                  1          1
# 18                    6.0         196                  2          0
# 19                    7.0         196                 17          0
# 20                    8.0         196                 14          1
# 21                    4.0         196                  9          0
# 22                    3.0         196                  1          1
# 23                    NaN         196                  4          0
# 24                    7.0         196                  5          1
# 25                    7.0         196                  3          1
# 26                    8.0         196                  6          1
# 27                    8.0         196                  5          1
# 28                    7.0         196                  5          1
# 29                    8.0         196                  4          1
# 30                    7.0         196                  3          1
# 31                    6.0         196                  7          1
# 32                    8.0         196                  3          1
# 33                    6.0         196                  4          1
# 34                   14.0         196                  6          1
# 35                    8.0         196                  4          1
# 36                   30.0         196                  1          1
# 37                    NaN         196                  1          0
# 38                    5.0         196                  2          1
# 39                    7.0         196                  2          1
# 40                    8.0         196                  1          1
# 41                    8.0         196                  2          1
# 42                    7.0         196                  2          1
# 43                    7.0         196                  1          1
# 44                    7.0         196                  1          1
# 45                    6.0         196                  1          1
# 46                    7.0         196                  1          1
# 47                    8.0         196                  1          1
# 48                    6.0         196                  1          1
# 49                    7.0         196                  1          1
#
#    product_name  aisle_id  department_id  prices    price_range_loc  \
# 0          Soda        77              7     9.0  Mid-range product
# 1          Soda        77              7     9.0  Mid-range product
# 2          Soda        77              7     9.0  Mid-range product
# 3          Soda        77              7     9.0  Mid-range product
# 4          Soda        77              7     9.0  Mid-range product
# 5          Soda        77              7     9.0  Mid-range product
# 6          Soda        77              7     9.0  Mid-range product
# 7          Soda        77              7     9.0  Mid-range product
# 8          Soda        77              7     9.0  Mid-range product
# 9          Soda        77              7     9.0  Mid-range product
# 10         Soda        77              7     9.0  Mid-range product
# 11         Soda        77              7     9.0  Mid-range product
# 12         Soda        77              7     9.0  Mid-range product
# 13         Soda        77              7     9.0  Mid-range product
# 14         Soda        77              7     9.0  Mid-range product
# 15         Soda        77              7     9.0  Mid-range product
# 16         Soda        77              7     9.0  Mid-range product
# 17         Soda        77              7     9.0  Mid-range product
# 18         Soda        77              7     9.0  Mid-range product
# 19         Soda        77              7     9.0  Mid-range product
# 20         Soda        77              7     9.0  Mid-range product
# 21         Soda        77              7     9.0  Mid-range product
# 22         Soda        77              7     9.0  Mid-range product
# 23         Soda        77              7     9.0  Mid-range product
# 24         Soda        77              7     9.0  Mid-range product
# 25         Soda        77              7     9.0  Mid-range product
# 26         Soda        77              7     9.0  Mid-range product
# 27         Soda        77              7     9.0  Mid-range product
# 28         Soda        77              7     9.0  Mid-range product
# 29         Soda        77              7     9.0  Mid-range product
# 30         Soda        77              7     9.0  Mid-range product
# 31         Soda        77              7     9.0  Mid-range product
# 32         Soda        77              7     9.0  Mid-range product
# 33         Soda        77              7     9.0  Mid-range product
# 34         Soda        77              7     9.0  Mid-range product
# 35         Soda        77              7     9.0  Mid-range product
# 36         Soda        77              7     9.0  Mid-range product
# 37         Soda        77              7     9.0  Mid-range product
# 38         Soda        77              7     9.0  Mid-range product
# 39         Soda        77              7     9.0  Mid-range product
# 40         Soda        77              7     9.0  Mid-range product
# 41         Soda        77              7     9.0  Mid-range product
# 42         Soda        77              7     9.0  Mid-range product
# 43         Soda        77              7     9.0  Mid-range product
# 44         Soda        77              7     9.0  Mid-range product
# 45         Soda        77              7     9.0  Mid-range product
# 46         Soda        77              7     9.0  Mid-range product
# 47         Soda        77              7     9.0  Mid-range product
# 48         Soda        77              7     9.0  Mid-range product
# 49         Soda        77              7     9.0  Mid-range product
#
#    busiest_day_of_week        busiest_days busiest_period_of_day  max_order
# 0       Regularly busy  Regularly busy day        Average orders         10
# 1       Regularly busy     Least busy days        Average orders         10
# 2       Regularly busy     Least busy days           Most orders         10
# 3           Least busy     Least busy days        Average orders         10
# 4           Least busy     Least busy days           Most orders         10
# 5       Regularly busy  Regularly busy day        Average orders         10
# 6       Regularly busy        Busiest days           Most orders         10
# 7       Regularly busy        Busiest days           Most orders         10
# 8       Regularly busy        Busiest days           Most orders         10
# 9           Least busy     Least busy days        Average orders         10
# 10      Regularly busy        Busiest days           Most orders         22
# 11      Regularly busy  Regularly busy day           Most orders         22
# 12      Regularly busy  Regularly busy day           Most orders         22
# 13      Regularly busy        Busiest days           Most orders         22
# 14      Regularly busy        Busiest days           Most orders         22
# 15      Regularly busy  Regularly busy day           Most orders          9
# 16      Regularly busy  Regularly busy day           Most orders          9
# 17          Least busy     Least busy days        Average orders          9
# 18      Regularly busy     Least busy days           Most orders         33
# 19      Regularly busy     Least busy days        Average orders         20
# 20      Regularly busy     Least busy days           Most orders         20
# 21          Least busy     Least busy days           Most orders         11
# 22          Least busy     Least busy days           Most orders         11
# 23      Regularly busy        Busiest days           Most orders         27
# 24      Regularly busy        Busiest days           Most orders         27
# 25      Regularly busy        Busiest days           Most orders         27
# 26      Regularly busy  Regularly busy day           Most orders         27
# 27      Regularly busy  Regularly busy day        Average orders         27
# 28      Regularly busy        Busiest days           Most orders         27
# 29      Regularly busy  Regularly busy day           Most orders         27
# 30      Regularly busy  Regularly busy day           Most orders         27
# 31      Regularly busy        Busiest days           Most orders         27
# 32      Regularly busy  Regularly busy day           Most orders         27
# 33      Regularly busy  Regularly busy day           Most orders         27
# 34      Regularly busy  Regularly busy day           Most orders         27
# 35      Regularly busy     Least busy days        Average orders         27
# 36      Regularly busy  Regularly busy day           Most orders         27
# 37      Regularly busy     Least busy days           Most orders         24
# 38      Regularly busy        Busiest days           Most orders         24
# 39      Regularly busy        Busiest days           Most orders         24
# 40      Regularly busy  Regularly busy day           Most orders         24
# 41      Regularly busy     Least busy days           Most orders         24
# 42      Regularly busy     Least busy days           Most orders         24
# 43      Regularly busy  Regularly busy day           Most orders         24
# 44      Regularly busy  Regularly busy day           Most orders         24
# 45      Regularly busy        Busiest days           Most orders         24
# 46      Regularly busy        Busiest days           Most orders         24
# 47      Regularly busy  Regularly busy day           Most orders         24
# 48      Regularly busy        Busiest days           Most orders         24
# 49      Regularly busy        Busiest days           Most orders         24

# %% [markdown]
# The new column (max_order) has been created

# %% [markdown]
# ## Creating a loyalty flag for existing customers

# %%
# Creating a new column with loc
df_ords_prods_merge.loc[df_ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
df_ords_prods_merge.loc[(df_ords_prods_merge['max_order'] <= 40) & (df_ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
df_ords_prods_merge.head(5)
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2398795        1             2                  3                  7
# 2    473747        1             3                  3                 12
# 3   2254736        1             4                  4                  7
# 4    431534        1             5                  4                 15
#
#    days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0                    NaN         196                  1          0
# 1                   15.0         196                  1          1
# 2                   21.0         196                  1          1
# 3                   29.0         196                  1          1
# 4                   28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices    price_range_loc  \
# 0         Soda        77              7     9.0  Mid-range product
# 1         Soda        77              7     9.0  Mid-range product
# 2         Soda        77              7     9.0  Mid-range product
# 3         Soda        77              7     9.0  Mid-range product
# 4         Soda        77              7     9.0  Mid-range product
#
#   busiest_day_of_week        busiest_days busiest_period_of_day  max_order  \
# 0      Regularly busy  Regularly busy day        Average orders         10
# 1      Regularly busy     Least busy days        Average orders         10
# 2      Regularly busy     Least busy days           Most orders         10
# 3          Least busy     Least busy days        Average orders         10
# 4          Least busy     Least busy days           Most orders         10
#
#    loyalty_flag
# 0  New customer
# 1  New customer
# 2  New customer
# 3  New customer
# 4  New customer

# %%
# Confirming the sum of all 3 new categories of customers created in the loyalty_flag column
df_ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %%
df_ords_prods_merge.shape
# Out:
# (32404859, 19)

# %% [markdown]
# The total number of customers based on loyalty is the same as the previous total so the code has been successfully executed.

# %% [markdown]
# ## Determining the prices of products purchased by each customer loyalty group

# %%
# Grouping by prices
df_ords_prods_merge.groupby('prices')

# %%
# Split the data into groups based on loyalty and then calculate the mean for each "prices" column
df_ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean']})
# Out:
#                      prices
#                        mean
# loyalty_flag
# Loyal customer    10.386336
# New customer      13.294670
# Regular customer  12.495717

# %% [markdown]
# Here we can see that the new customers tend to buy the more expensive products on average. There is not much difference and as we already know that the loyal customers tend to buy more, I believe they are still the most important group.

# %% [markdown]
# ## Determining the average prices spent by customers

# %%
# Splitting into groups and generating a new column for average_price
df_ords_prods_merge['avg_price'] = df_ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)
# This will create a new column with the average price for each user_id

# %%
df_ords_prods_merge.head(50)
# Out:
#     order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                  2                  8
# 1    2398795        1             2                  3                  7
# 2     473747        1             3                  3                 12
# 3    2254736        1             4                  4                  7
# 4     431534        1             5                  4                 15
# 5    3367565        1             6                  2                  7
# 6     550135        1             7                  1                  9
# 7    3108588        1             8                  1                 14
# 8    2295261        1             9                  1                 16
# 9    2550362        1            10                  4                  8
# 10   2968173       15            15                  1                  9
# 11   1870022       15            17                  2                 16
# 12   1911383       15            18                  2                 11
# 13   2715276       15            21                  1                  9
# 14    487368       15            22                  1                 10
# 15   2293453       19             2                  5                 14
# 16   1973799       19             5                  6                 12
# 17    532817       19             7                  4                 17
# 18   1573906       21            10                  3                 10
# 19   1593000       31            10                  3                  8
# 20   2231262       31            17                  3                 11
# 21   2580647       43             6                  4                 16
# 22   2187180       43             9                  4                 12
# 23   2497897       52             1                  1                  9
# 24   1318871       52             2                  1                 10
# 25   1261384       52             3                  1                 10
# 26    580568       52             5                  2                 10
# 27   2428073       52             7                  2                  7
# 28    342306       52             9                  1                 11
# 29   1520353       52            10                  2                 10
# 30   2542086       52            11                  2                  9
# 31    944694       52            12                  1                 16
# 32   1268191       52            15                  2                 11
# 33   1122089       52            17                  2                 10
# 34   1498922       52            18                  2                 10
# 35    180919       52            19                  3                  8
# 36   2695875       52            21                  5                 10
# 37   3205960       67             1                  3                 11
# 38    970922       67             2                  1                 15
# 39    596585       67             3                  1                 13
# 40   2037087       67             4                  2                  9
# 41   2474111       67             5                  3                 14
# 42   1568481       67             6                  3                 12
# 43   2048527       67             8                  2                 11
# 44   2389031       67             9                  2                 14
# 45   2378562       67            10                  1                 10
# 46   1515698       67            11                  1                 11
# 47   1928050       67            12                  2                 12
# 48   1949274       67            13                  1                 10
# 49    551869       67            14                  1                  9
#
#     days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
# 5                    19.0         196                  1          1
# 6                    20.0         196                  1          1
# 7                    14.0         196                  2          1
# 8                     0.0         196                  4          1
# 9                    30.0         196                  1          1
# 10                    7.0         196                  2          0
# 11                    8.0         196                  6          1
# 12                    7.0         196                  1          1
# 13                    7.0         196                  1          1
# 14                   14.0         196                  1          1
# 15                    6.0         196                  3          0
# 16                    8.0         196                 15          1
# 17                    6.0         196                  1          1
# 18                    6.0         196                  2          0
# 19                    7.0         196                 17          0
# 20                    8.0         196                 14          1
# 21                    4.0         196                  9          0
# 22                    3.0         196                  1          1
# 23                    NaN         196                  4          0
# 24                    7.0         196                  5          1
# 25                    7.0         196                  3          1
# 26                    8.0         196                  6          1
# 27                    8.0         196                  5          1
# 28                    7.0         196                  5          1
# 29                    8.0         196                  4          1
# 30                    7.0         196                  3          1
# 31                    6.0         196                  7          1
# 32                    8.0         196                  3          1
# 33                    6.0         196                  4          1
# 34                   14.0         196                  6          1
# 35                    8.0         196                  4          1
# 36                   30.0         196                  1          1
# 37                    NaN         196                  1          0
# 38                    5.0         196                  2          1
# 39                    7.0         196                  2          1
# 40                    8.0         196                  1          1
# 41                    8.0         196                  2          1
# 42                    7.0         196                  2          1
# 43                    7.0         196                  1          1
# 44                    7.0         196                  1          1
# 45                    6.0         196                  1          1
# 46                    7.0         196                  1          1
# 47                    8.0         196                  1          1
# 48                    6.0         196                  1          1
# 49                    7.0         196                  1          1
#
#    product_name  aisle_id  department_id  prices    price_range_loc  \
# 0          Soda        77              7     9.0  Mid-range product
# 1          Soda        77              7     9.0  Mid-range product
# 2          Soda        77              7     9.0  Mid-range product
# 3          Soda        77              7     9.0  Mid-range product
# 4          Soda        77              7     9.0  Mid-range product
# 5          Soda        77              7     9.0  Mid-range product
# 6          Soda        77              7     9.0  Mid-range product
# 7          Soda        77              7     9.0  Mid-range product
# 8          Soda        77              7     9.0  Mid-range product
# 9          Soda        77              7     9.0  Mid-range product
# 10         Soda        77              7     9.0  Mid-range product
# 11         Soda        77              7     9.0  Mid-range product
# 12         Soda        77              7     9.0  Mid-range product
# 13         Soda        77              7     9.0  Mid-range product
# 14         Soda        77              7     9.0  Mid-range product
# 15         Soda        77              7     9.0  Mid-range product
# 16         Soda        77              7     9.0  Mid-range product
# 17         Soda        77              7     9.0  Mid-range product
# 18         Soda        77              7     9.0  Mid-range product
# 19         Soda        77              7     9.0  Mid-range product
# 20         Soda        77              7     9.0  Mid-range product
# 21         Soda        77              7     9.0  Mid-range product
# 22         Soda        77              7     9.0  Mid-range product
# 23         Soda        77              7     9.0  Mid-range product
# 24         Soda        77              7     9.0  Mid-range product
# 25         Soda        77              7     9.0  Mid-range product
# 26         Soda        77              7     9.0  Mid-range product
# 27         Soda        77              7     9.0  Mid-range product
# 28         Soda        77              7     9.0  Mid-range product
# 29         Soda        77              7     9.0  Mid-range product
# 30         Soda        77              7     9.0  Mid-range product
# 31         Soda        77              7     9.0  Mid-range product
# 32         Soda        77              7     9.0  Mid-range product
# 33         Soda        77              7     9.0  Mid-range product
# 34         Soda        77              7     9.0  Mid-range product
# 35         Soda        77              7     9.0  Mid-range product
# 36         Soda        77              7     9.0  Mid-range product
# 37         Soda        77              7     9.0  Mid-range product
# 38         Soda        77              7     9.0  Mid-range product
# 39         Soda        77              7     9.0  Mid-range product
# 40         Soda        77              7     9.0  Mid-range product
# 41         Soda        77              7     9.0  Mid-range product
# 42         Soda        77              7     9.0  Mid-range product
# 43         Soda        77              7     9.0  Mid-range product
# 44         Soda        77              7     9.0  Mid-range product
# 45         Soda        77              7     9.0  Mid-range product
# 46         Soda        77              7     9.0  Mid-range product
# 47         Soda        77              7     9.0  Mid-range product
# 48         Soda        77              7     9.0  Mid-range product
# 49         Soda        77              7     9.0  Mid-range product
#
#    busiest_day_of_week        busiest_days busiest_period_of_day  max_order  \
# 0       Regularly busy  Regularly busy day        Average orders         10
# 1       Regularly busy     Least busy days        Average orders         10
# 2       Regularly busy     Least busy days           Most orders         10
# 3           Least busy     Least busy days        Average orders         10
# 4           Least busy     Least busy days           Most orders         10
# 5       Regularly busy  Regularly busy day        Average orders         10
# 6       Regularly busy        Busiest days           Most orders         10
# 7       Regularly busy        Busiest days           Most orders         10
# 8       Regularly busy        Busiest days           Most orders         10
# 9           Least busy     Least busy days        Average orders         10
# 10      Regularly busy        Busiest days           Most orders         22
# 11      Regularly busy  Regularly busy day           Most orders         22
# 12      Regularly busy  Regularly busy day           Most orders         22
# 13      Regularly busy        Busiest days           Most orders         22
# 14      Regularly busy        Busiest days           Most orders         22
# 15      Regularly busy  Regularly busy day           Most orders          9
# 16      Regularly busy  Regularly busy day           Most orders          9
# 17          Least busy     Least busy days        Average orders          9
# 18      Regularly busy     Least busy days           Most orders         33
# 19      Regularly busy     Least busy days        Average orders         20
# 20      Regularly busy     Least busy days           Most orders         20
# 21          Least busy     Least busy days           Most orders         11
# 22          Least busy     Least busy days           Most orders         11
# 23      Regularly busy        Busiest days           Most orders         27
# 24      Regularly busy        Busiest days           Most orders         27
# 25      Regularly busy        Busiest days           Most orders         27
# 26      Regularly busy  Regularly busy day           Most orders         27
# 27      Regularly busy  Regularly busy day        Average orders         27
# 28      Regularly busy        Busiest days           Most orders         27
# 29      Regularly busy  Regularly busy day           Most orders         27
# 30      Regularly busy  Regularly busy day           Most orders         27
# 31      Regularly busy        Busiest days           Most orders         27
# 32      Regularly busy  Regularly busy day           Most orders         27
# 33      Regularly busy  Regularly busy day           Most orders         27
# 34      Regularly busy  Regularly busy day           Most orders         27
# 35      Regularly busy     Least busy days        Average orders         27
# 36      Regularly busy  Regularly busy day           Most orders         27
# 37      Regularly busy     Least busy days           Most orders         24
# 38      Regularly busy        Busiest days           Most orders         24
# 39      Regularly busy        Busiest days           Most orders         24
# 40      Regularly busy  Regularly busy day           Most orders         24
# 41      Regularly busy     Least busy days           Most orders         24
# 42      Regularly busy     Least busy days           Most orders         24
# 43      Regularly busy  Regularly busy day           Most orders         24
# 44      Regularly busy  Regularly busy day           Most orders         24
# 45      Regularly busy        Busiest days           Most orders         24
# 46      Regularly busy        Busiest days           Most orders         24
# 47      Regularly busy  Regularly busy day           Most orders         24
# 48      Regularly busy        Busiest days           Most orders         24
# 49      Regularly busy        Busiest days           Most orders         24
#
#         loyalty_flag  avg_price
# 0       New customer   6.367797
# 1       New customer   6.367797
# 2       New customer   6.367797
# 3       New customer   6.367797
# 4       New customer   6.367797
# 5       New customer   6.367797
# 6       New customer   6.367797
# 7       New customer   6.367797
# 8       New customer   6.367797
# 9       New customer   6.367797
# 10  Regular customer   3.980556
# 11  Regular customer   3.980556
# 12  Regular customer   3.980556
# 13  Regular customer   3.980556
# 14  Regular customer   3.980556
# 15      New customer   8.372059
# 16      New customer   8.372059
# 17      New customer   8.372059
# 18  Regular customer   7.012683
# 19  Regular customer   8.137793
# 20  Regular customer   8.137793
# 21  Regular customer   7.444898
# 22  Regular customer   7.444898
# 23  Regular customer   6.356287
# 24  Regular customer   6.356287
# 25  Regular customer   6.356287
# 26  Regular customer   6.356287
# 27  Regular customer   6.356287
# 28  Regular customer   6.356287
# 29  Regular customer   6.356287
# 30  Regular customer   6.356287
# 31  Regular customer   6.356287
# 32  Regular customer   6.356287
# 33  Regular customer   6.356287
# 34  Regular customer   6.356287
# 35  Regular customer   6.356287
# 36  Regular customer   6.356287
# 37  Regular customer   7.656790
# 38  Regular customer   7.656790
# 39  Regular customer   7.656790
# 40  Regular customer   7.656790
# 41  Regular customer   7.656790
# 42  Regular customer   7.656790
# 43  Regular customer   7.656790
# 44  Regular customer   7.656790
# 45  Regular customer   7.656790
# 46  Regular customer   7.656790
# 47  Regular customer   7.656790
# 48  Regular customer   7.656790
# 49  Regular customer   7.656790

# %% [markdown]
# ## Creating a spending flag for customers based on average prices spent

# %%
# Creating a new column with loc
df_ords_prods_merge.loc[df_ords_prods_merge['avg_price'] >= 10, 'spending_flag'] = 'High spender'

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['avg_price'] < 10, 'spending_flag'] = 'Low spender'

# %%
# Checking the sum of the values under spending_flag to confirm accuracy 
df_ords_prods_merge['spending_flag'].value_counts(dropna = False)
# Out:
# Low spender     31770614
# High spender      634245
# Name: spending_flag, dtype: int64

# %% [markdown]
# There are 31770614 low spenders and 634245 high spenders. The high spenders are the majority with 98% of the total number of customers.

# %%
df_ords_prods_merge.shape
# Out:
# (32404859, 21)

# %% [markdown]
# The total number of customers based on spending is the same as the previous total so the code has been successfully executed. Also, we have a lot more low spenders than high spenders based on average prices.

# %% [markdown]
# ## Determining the frequency of customers' shopping based on days since last order

# %%
# Splitting into groups and generating a new column for median days
df_ords_prods_merge['median_days'] = df_ords_prods_merge.groupby(['user_id'])['days_since_last_order'].transform(np.median)
# This will create a new column with the median days for each user_id

# %%
df_ords_prods_merge.head(50)
# Out:
#     order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                  2                  8
# 1    2398795        1             2                  3                  7
# 2     473747        1             3                  3                 12
# 3    2254736        1             4                  4                  7
# 4     431534        1             5                  4                 15
# 5    3367565        1             6                  2                  7
# 6     550135        1             7                  1                  9
# 7    3108588        1             8                  1                 14
# 8    2295261        1             9                  1                 16
# 9    2550362        1            10                  4                  8
# 10   2968173       15            15                  1                  9
# 11   1870022       15            17                  2                 16
# 12   1911383       15            18                  2                 11
# 13   2715276       15            21                  1                  9
# 14    487368       15            22                  1                 10
# 15   2293453       19             2                  5                 14
# 16   1973799       19             5                  6                 12
# 17    532817       19             7                  4                 17
# 18   1573906       21            10                  3                 10
# 19   1593000       31            10                  3                  8
# 20   2231262       31            17                  3                 11
# 21   2580647       43             6                  4                 16
# 22   2187180       43             9                  4                 12
# 23   2497897       52             1                  1                  9
# 24   1318871       52             2                  1                 10
# 25   1261384       52             3                  1                 10
# 26    580568       52             5                  2                 10
# 27   2428073       52             7                  2                  7
# 28    342306       52             9                  1                 11
# 29   1520353       52            10                  2                 10
# 30   2542086       52            11                  2                  9
# 31    944694       52            12                  1                 16
# 32   1268191       52            15                  2                 11
# 33   1122089       52            17                  2                 10
# 34   1498922       52            18                  2                 10
# 35    180919       52            19                  3                  8
# 36   2695875       52            21                  5                 10
# 37   3205960       67             1                  3                 11
# 38    970922       67             2                  1                 15
# 39    596585       67             3                  1                 13
# 40   2037087       67             4                  2                  9
# 41   2474111       67             5                  3                 14
# 42   1568481       67             6                  3                 12
# 43   2048527       67             8                  2                 11
# 44   2389031       67             9                  2                 14
# 45   2378562       67            10                  1                 10
# 46   1515698       67            11                  1                 11
# 47   1928050       67            12                  2                 12
# 48   1949274       67            13                  1                 10
# 49    551869       67            14                  1                  9
#
#     days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
# 5                    19.0         196                  1          1
# 6                    20.0         196                  1          1
# 7                    14.0         196                  2          1
# 8                     0.0         196                  4          1
# 9                    30.0         196                  1          1
# 10                    7.0         196                  2          0
# 11                    8.0         196                  6          1
# 12                    7.0         196                  1          1
# 13                    7.0         196                  1          1
# 14                   14.0         196                  1          1
# 15                    6.0         196                  3          0
# 16                    8.0         196                 15          1
# 17                    6.0         196                  1          1
# 18                    6.0         196                  2          0
# 19                    7.0         196                 17          0
# 20                    8.0         196                 14          1
# 21                    4.0         196                  9          0
# 22                    3.0         196                  1          1
# 23                    NaN         196                  4          0
# 24                    7.0         196                  5          1
# 25                    7.0         196                  3          1
# 26                    8.0         196                  6          1
# 27                    8.0         196                  5          1
# 28                    7.0         196                  5          1
# 29                    8.0         196                  4          1
# 30                    7.0         196                  3          1
# 31                    6.0         196                  7          1
# 32                    8.0         196                  3          1
# 33                    6.0         196                  4          1
# 34                   14.0         196                  6          1
# 35                    8.0         196                  4          1
# 36                   30.0         196                  1          1
# 37                    NaN         196                  1          0
# 38                    5.0         196                  2          1
# 39                    7.0         196                  2          1
# 40                    8.0         196                  1          1
# 41                    8.0         196                  2          1
# 42                    7.0         196                  2          1
# 43                    7.0         196                  1          1
# 44                    7.0         196                  1          1
# 45                    6.0         196                  1          1
# 46                    7.0         196                  1          1
# 47                    8.0         196                  1          1
# 48                    6.0         196                  1          1
# 49                    7.0         196                  1          1
#
#    product_name  ...  prices    price_range_loc  busiest_day_of_week  \
# 0          Soda  ...     9.0  Mid-range product       Regularly busy
# 1          Soda  ...     9.0  Mid-range product       Regularly busy
# 2          Soda  ...     9.0  Mid-range product       Regularly busy
# 3          Soda  ...     9.0  Mid-range product           Least busy
# 4          Soda  ...     9.0  Mid-range product           Least busy
# 5          Soda  ...     9.0  Mid-range product       Regularly busy
# 6          Soda  ...     9.0  Mid-range product       Regularly busy
# 7          Soda  ...     9.0  Mid-range product       Regularly busy
# 8          Soda  ...     9.0  Mid-range product       Regularly busy
# 9          Soda  ...     9.0  Mid-range product           Least busy
# 10         Soda  ...     9.0  Mid-range product       Regularly busy
# 11         Soda  ...     9.0  Mid-range product       Regularly busy
# 12         Soda  ...     9.0  Mid-range product       Regularly busy
# 13         Soda  ...     9.0  Mid-range product       Regularly busy
# 14         Soda  ...     9.0  Mid-range product       Regularly busy
# 15         Soda  ...     9.0  Mid-range product       Regularly busy
# 16         Soda  ...     9.0  Mid-range product       Regularly busy
# 17         Soda  ...     9.0  Mid-range product           Least busy
# 18         Soda  ...     9.0  Mid-range product       Regularly busy
# 19         Soda  ...     9.0  Mid-range product       Regularly busy
# 20         Soda  ...     9.0  Mid-range product       Regularly busy
# 21         Soda  ...     9.0  Mid-range product           Least busy
# 22         Soda  ...     9.0  Mid-range product           Least busy
# 23         Soda  ...     9.0  Mid-range product       Regularly busy
# 24         Soda  ...     9.0  Mid-range product       Regularly busy
# 25         Soda  ...     9.0  Mid-range product       Regularly busy
# 26         Soda  ...     9.0  Mid-range product       Regularly busy
# 27         Soda  ...     9.0  Mid-range product       Regularly busy
# 28         Soda  ...     9.0  Mid-range product       Regularly busy
# 29         Soda  ...     9.0  Mid-range product       Regularly busy
# 30         Soda  ...     9.0  Mid-range product       Regularly busy
# 31         Soda  ...     9.0  Mid-range product       Regularly busy
# 32         Soda  ...     9.0  Mid-range product       Regularly busy
# 33         Soda  ...     9.0  Mid-range product       Regularly busy
# 34         Soda  ...     9.0  Mid-range product       Regularly busy
# 35         Soda  ...     9.0  Mid-range product       Regularly busy
# 36         Soda  ...     9.0  Mid-range product       Regularly busy
# 37         Soda  ...     9.0  Mid-range product       Regularly busy
# 38         Soda  ...     9.0  Mid-range product       Regularly busy
# 39         Soda  ...     9.0  Mid-range product       Regularly busy
# 40         Soda  ...     9.0  Mid-range product       Regularly busy
# 41         Soda  ...     9.0  Mid-range product       Regularly busy
# 42         Soda  ...     9.0  Mid-range product       Regularly busy
# 43         Soda  ...     9.0  Mid-range product       Regularly busy
# 44         Soda  ...     9.0  Mid-range product       Regularly busy
# 45         Soda  ...     9.0  Mid-range product       Regularly busy
# 46         Soda  ...     9.0  Mid-range product       Regularly busy
# 47         Soda  ...     9.0  Mid-range product       Regularly busy
# 48         Soda  ...     9.0  Mid-range product       Regularly busy
# 49         Soda  ...     9.0  Mid-range product       Regularly busy
#
#           busiest_days busiest_period_of_day max_order      loyalty_flag  \
# 0   Regularly busy day        Average orders        10      New customer
# 1      Least busy days        Average orders        10      New customer
# 2      Least busy days           Most orders        10      New customer
# 3      Least busy days        Average orders        10      New customer
# 4      Least busy days           Most orders        10      New customer
# 5   Regularly busy day        Average orders        10      New customer
# 6         Busiest days           Most orders        10      New customer
# 7         Busiest days           Most orders        10      New customer
# 8         Busiest days           Most orders        10      New customer
# 9      Least busy days        Average orders        10      New customer
# 10        Busiest days           Most orders        22  Regular customer
# 11  Regularly busy day           Most orders        22  Regular customer
# 12  Regularly busy day           Most orders        22  Regular customer
# 13        Busiest days           Most orders        22  Regular customer
# 14        Busiest days           Most orders        22  Regular customer
# 15  Regularly busy day           Most orders         9      New customer
# 16  Regularly busy day           Most orders         9      New customer
# 17     Least busy days        Average orders         9      New customer
# 18     Least busy days           Most orders        33  Regular customer
# 19     Least busy days        Average orders        20  Regular customer
# 20     Least busy days           Most orders        20  Regular customer
# 21     Least busy days           Most orders        11  Regular customer
# 22     Least busy days           Most orders        11  Regular customer
# 23        Busiest days           Most orders        27  Regular customer
# 24        Busiest days           Most orders        27  Regular customer
# 25        Busiest days           Most orders        27  Regular customer
# 26  Regularly busy day           Most orders        27  Regular customer
# 27  Regularly busy day        Average orders        27  Regular customer
# 28        Busiest days           Most orders        27  Regular customer
# 29  Regularly busy day           Most orders        27  Regular customer
# 30  Regularly busy day           Most orders        27  Regular customer
# 31        Busiest days           Most orders        27  Regular customer
# 32  Regularly busy day           Most orders        27  Regular customer
# 33  Regularly busy day           Most orders        27  Regular customer
# 34  Regularly busy day           Most orders        27  Regular customer
# 35     Least busy days        Average orders        27  Regular customer
# 36  Regularly busy day           Most orders        27  Regular customer
# 37     Least busy days           Most orders        24  Regular customer
# 38        Busiest days           Most orders        24  Regular customer
# 39        Busiest days           Most orders        24  Regular customer
# 40  Regularly busy day           Most orders        24  Regular customer
# 41     Least busy days           Most orders        24  Regular customer
# 42     Least busy days           Most orders        24  Regular customer
# 43  Regularly busy day           Most orders        24  Regular customer
# 44  Regularly busy day           Most orders        24  Regular customer
# 45        Busiest days           Most orders        24  Regular customer
# 46        Busiest days           Most orders        24  Regular customer
# 47  Regularly busy day           Most orders        24  Regular customer
# 48        Busiest days           Most orders        24  Regular customer
# 49        Busiest days           Most orders        24  Regular customer
#
#     avg_price spending_flag  median_days
# 0    6.367797   Low spender         20.5
# 1    6.367797   Low spender         20.5
# 2    6.367797   Low spender         20.5
# 3    6.367797   Low spender         20.5
# 4    6.367797   Low spender         20.5
# 5    6.367797   Low spender         20.5
# 6    6.367797   Low spender         20.5
# 7    6.367797   Low spender         20.5
# 8    6.367797   Low spender         20.5
# 9    6.367797   Low spender         20.5
# 10   3.980556   Low spender         10.0
# 11   3.980556   Low spender         10.0
# 12   3.980556   Low spender         10.0
# 13   3.980556   Low spender         10.0
# 14   3.980556   Low spender         10.0
# 15   8.372059   Low spender          6.0
# 16   8.372059   Low spender          6.0
# 17   8.372059   Low spender          6.0
# 18   7.012683   Low spender          7.5
# 19   8.137793   Low spender          6.0
# 20   8.137793   Low spender          6.0
# 21   7.444898   Low spender         10.0
# 22   7.444898   Low spender         10.0
# 23   6.356287   Low spender          8.0
# 24   6.356287   Low spender          8.0
# 25   6.356287   Low spender          8.0
# 26   6.356287   Low spender          8.0
# 27   6.356287   Low spender          8.0
# 28   6.356287   Low spender          8.0
# 29   6.356287   Low spender          8.0
# 30   6.356287   Low spender          8.0
# 31   6.356287   Low spender          8.0
# 32   6.356287   Low spender          8.0
# 33   6.356287   Low spender          8.0
# 34   6.356287   Low spender          8.0
# 35   6.356287   Low spender          8.0
# 36   6.356287   Low spender          8.0
# 37   7.656790   Low spender          7.0
# 38   7.656790   Low spender          7.0
# 39   7.656790   Low spender          7.0
# 40   7.656790   Low spender          7.0
# 41   7.656790   Low spender          7.0
# 42   7.656790   Low spender          7.0
# 43   7.656790   Low spender          7.0
# 44   7.656790   Low spender          7.0
# 45   7.656790   Low spender          7.0
# 46   7.656790   Low spender          7.0
# 47   7.656790   Low spender          7.0
# 48   7.656790   Low spender          7.0
# 49   7.656790   Low spender          7.0
#
# [50 rows x 22 columns]

# %% [markdown]
# ## Creating an order frequency flag based on median days since last order

# %%
# Creating a new column with loc
df_ords_prods_merge.loc[df_ords_prods_merge['median_days'] > 20, 'order_frequency_flag'] = 'Non-frequent customer'

# %%
df_ords_prods_merge.loc[(df_ords_prods_merge['median_days'] <= 20) & (df_ords_prods_merge['median_days'] > 10), 'order_frequency_flag'] = 'Regular customer'

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['median_days'] <= 10, 'order_frequency_flag'] = 'Frequent customer'

# %%
# Checking the sum of the values under order_frequency_flag to confirm accuracy 
df_ords_prods_merge['order_frequency_flag'].value_counts(dropna = False)
# Out:
# Frequent customer        21559853
# Regular customer          7208564
# Non-frequent customer     3636437
# NaN                             5
# Name: order_frequency_flag, dtype: int64

# %% [markdown]
# We have a majority of frequent customers based on median days but we also have 5 under NaN (unknown values)

# %%
# To find out what category the NaN values fall under
print(df_ords_prods_merge[df_ords_prods_merge.order_frequency_flag.isnull()])
# This will return all rows where the order_frequency_flag is null
# Out:
#           order_id  user_id  order_number  order_day_of_week  \
# 13645692    895835   159838             1                  0
# 17251990    895835   159838             1                  0
# 17622767    895835   159838             1                  0
# 24138593    895835   159838             1                  0
# 25880002    895835   159838             1                  0
#
#           order_hour_of_day  days_since_last_order  product_id  \
# 13645692                 17                    NaN       10749
# 17251990                 17                    NaN       33401
# 17622767                 17                    NaN       23695
# 24138593                 17                    NaN       21334
# 25880002                 17                    NaN       22198
#
#           add_to_cart_order  reordered  \
# 13645692                  3          0
# 17251990                  6          0
# 17622767                  2          0
# 24138593                  5          0
# 25880002                  1          0
#
#                                                product_name  ...  \
# 13645692                            Organic Red Bell Pepper  ...
# 17251990                               Goat Cheese Crumbles  ...
# 17622767                           California Veggie Burger  ...
# 24138593                              Organic Peeled Garlic  ...
# 25880002  4X Ultra Concentrated Natural Laundry Detergen...  ...
#
#             price_range_loc  busiest_day_of_week  busiest_days  \
# 13645692  Mid-range product          Busiest day  Busiest days
# 17251990  Mid-range product          Busiest day  Busiest days
# 17622767  Low-range product          Busiest day  Busiest days
# 24138593  Mid-range product          Busiest day  Busiest days
# 25880002  Low-range product          Busiest day  Busiest days
#
#          busiest_period_of_day max_order  loyalty_flag avg_price  \
# 13645692        Average orders         1  New customer      7.42
# 17251990        Average orders         1  New customer      7.42
# 17622767        Average orders         1  New customer      7.42
# 24138593        Average orders         1  New customer      7.42
# 25880002        Average orders         1  New customer      7.42
#
#           spending_flag median_days  order_frequency_flag
# 13645692    Low spender         NaN                   NaN
# 17251990    Low spender         NaN                   NaN
# 17622767    Low spender         NaN                   NaN
# 24138593    Low spender         NaN                   NaN
# 25880002    Low spender         NaN                   NaN
#
# [5 rows x 23 columns]

# %% [markdown]
# As confirmed earlier, there are 5 rows with null values. These values fall under just 1 user_id (159838) with one order_id (895835). This means that this customer has only had one order and therefore we can't calculate median days. Since the criteria for grouping states that grouping have to be made based on median days, I believe we can categorise this customer under 'Non-frequent' as they have never returned to shop.

# %%
# we can change the null values in "order_frequency_flag" column to Non-frequent customer
df_ords_prods_merge['order_frequency_flag'].fillna("Non-frequent customer", inplace = True)
# This will replace all NaN values

# %%
# Checking the sum of the values under order_frequency_flag to confirm accuracy 
df_ords_prods_merge['order_frequency_flag'].value_counts(dropna = False)
# Out:
# Frequent customer        21559853
# Regular customer          7208564
# Non-frequent customer     3636442
# Name: order_frequency_flag, dtype: int64

# %% [markdown]
# Now, there are no NaN values anymore

# %% [markdown]
# We have 21,559,853 frequent customers and 3,636,442 non-frequent customers. The frequent customers are the majority with 66.5% of the total customer numbers. Non-frequent customers occupy just 1.1% of the total customer numbers.

# %% [markdown]
# ## Exporting dataframe to pickle

# %%
# Export data to pickle
df_ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_aggregated.pkl'))
